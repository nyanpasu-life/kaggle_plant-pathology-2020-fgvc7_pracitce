# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/plant-pathology-2020-fgvc7/sample_submission.csv
# /kaggle/input/plant-pathology-2020-fgvc7/train.csv
# /kaggle/input/plant-pathology-2020-fgvc7/test.csv
# /kaggle/input/plant-pathology-2020-fgvc7/images/Test_1743.jpg
# /kaggle/input/plant-pathology-2020-fgvc7/images/Test_262.jpg
# /kaggle/input/plant-pathology-2020-fgvc7/images/Train_1524.jpg
# /kaggle/input/plant-pathology-2020-fgvc7/images/Train_1336.jpg
# /kaggle/input/plant-pathology-2020-fgvc7/images/Train_1461.jpg
# /kaggle/input/plant-pathology-2020-fgvc7/images/Train_1797.jpg
# /kaggle/input/plant-pathology-2020-fgvc7/images/Test_1499.jpg
# /kaggle/input/plant-pathology-2020-fgvc7/images/Train_1170.jpg
# /kaggle/input/plant-pathology-2020-fgvc7/images/Test_1259.jpg
# /kaggle/input/plant-pathology-2020-fgvc7/images/Test_422.jpg
# /kaggle/input/plant-pathology-2020-fgvc7/images/Test_636.jpg
# /kaggle/input/plant-pathology-2020-fgvc7/images/Test_1395.jpg
# ...

# %%
df = pd.read_csv("/kaggle/input/plant-pathology-2020-fgvc7/train.csv")
df.head(3)
# Out:
#   image_id  healthy  multiple_diseases  rust  scab
# 0  Train_0        0                  0     0     1
# 1  Train_1        0                  1     0     0
# 2  Train_2        1                  0     0     0

# %%
df.columns
# Out:
# Index(['image_id', 'healthy', 'multiple_diseases', 'rust', 'scab'], dtype='object')

# %%
import matplotlib.pyplot as plt
import cv2

# %%
import os

file_names_list = []
file_number = []
file_names = os.listdir('/kaggle/input/plant-pathology-2020-fgvc7/images')
for idx, filename in enumerate(file_names):
    file_names_list.append(filename.split('.')[0])
for i in file_names_list:
    file_number.append(i.split('_')[1])

# %%
df[df['rust'] == 1].count()
# Out:
# image_id             622
# healthy              622
# multiple_diseases    622
# rust                 622
# scab                 622
# dtype: int64

# %%
health_img_1 = cv2.imread('/kaggle/input/plant-pathology-2020-fgvc7/images/Train_2.jpg')
health_img_2 = cv2.imread('/kaggle/input/plant-pathology-2020-fgvc7/images/Train_4.jpg')
mul_dis_img_1 = cv2.imread('/kaggle/input/plant-pathology-2020-fgvc7/images/Train_1.jpg')
mul_dis_img_2 = cv2.imread('/kaggle/input/plant-pathology-2020-fgvc7/images/Train_6.jpg')
rust_img_1 = cv2.imread('/kaggle/input/plant-pathology-2020-fgvc7/images/Train_3.jpg')
rust_img_2 = cv2.imread('/kaggle/input/plant-pathology-2020-fgvc7/images/Train_10.jpg')
scab_img_1 = cv2.imread('/kaggle/input/plant-pathology-2020-fgvc7/images/Train_0.jpg')
scab_img_2 = cv2.imread('/kaggle/input/plant-pathology-2020-fgvc7/images/Train_7.jpg')

fig = plt.figure()

ax1 = fig.add_subplot(2, 4, 1)
ax1.imshow(cv2.cvtColor(health_img_1, cv2.COLOR_BGR2RGB))
ax1.set_title('Healthy 1')
ax1.axis("off")

ax2 = fig.add_subplot(2, 4, 2)
ax2.imshow(cv2.cvtColor(health_img_2, cv2.COLOR_BGR2RGB))
ax2.set_title('Healthy 2')
ax2.axis("off")

ax1 = fig.add_subplot(2, 4, 3)
ax1.imshow(cv2.cvtColor(mul_dis_img_1, cv2.COLOR_BGR2RGB))
ax1.set_title('Multiple_Disease 1')
ax1.axis("off")

ax2 = fig.add_subplot(2, 4, 4)
ax2.imshow(cv2.cvtColor(mul_dis_img_2, cv2.COLOR_BGR2RGB))
ax2.set_title('Multiple_Disease 2')
ax2.axis("off")

ax1 = fig.add_subplot(2, 4, 5)
ax1.imshow(cv2.cvtColor(rust_img_1, cv2.COLOR_BGR2RGB))
ax1.set_title('rust 1')
ax1.axis("off")

ax2 = fig.add_subplot(2, 4, 6)
ax2.imshow(cv2.cvtColor(rust_img_2, cv2.COLOR_BGR2RGB))
ax2.set_title('rust 2')
ax2.axis("off")

ax1 = fig.add_subplot(2, 4, 7)
ax1.imshow(cv2.cvtColor(scab_img_1, cv2.COLOR_BGR2RGB))
ax1.set_title('scab 1')
ax1.axis("off")

ax2 = fig.add_subplot(2, 4, 8)
ax2.imshow(cv2.cvtColor(scab_img_2, cv2.COLOR_BGR2RGB))
ax2.set_title('scab 2')
ax2.axis("off")

plt.show()

# %%
df[df['scab'] == 1].count()
# Out:
# image_id             592
# healthy              592
# multiple_diseases    592
# rust                 592
# scab                 592
# dtype: int64

# %%
ratio = [516, 91, 622, 592]
labels = ['healthy', 'multiple_diseases', 'rust', 'scab']

# %%
plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.show()

# %% [markdown]
# # DATESET 의 근본적인 문제

# %%
import pandas as pd
import matplotlib.pyplot as plt
import cv2

# %%
train_data = pd.read_csv("./plant-pathology-2020-fgvc7/train.csv")

img_379 = cv2.imread('./plant-pathology-2020-fgvc7/images/Train_379.jpg')
img_379_label = train_data.iloc[379][:]

img_1173 = cv2.imread('./plant-pathology-2020-fgvc7/images/Train_1173.jpg')
img_1173_label = train_data.iloc[1173][:]

plt.imshow(cv2.cvtColor(img_379, cv2.COLOR_BGR2RGB))
plt.show()
print(img_379_label)

plt.imshow(cv2.cvtColor(img_1173, cv2.COLOR_BGR2RGB))
plt.show()
print(img_1173_label)
# Out:
# image_id             Train_379
# healthy                      0
# multiple_diseases            0
# rust                         0
# scab                         1
# Name: 379, dtype: object
# image_id             Train_1173
# healthy                       0
# multiple_diseases             1
# rust                          0
# scab                          0
# Name: 1173, dtype: object

# %% [markdown]
# ### 동일한 사진인데 라벨링이 다르게 되어있음!

# %%
img_1 = cv2.imread('./plant-pathology-2020-fgvc7/images/Train_1.jpg')
img_1_label = train_data.iloc[1][:]

img_171 = cv2.imread('./plant-pathology-2020-fgvc7/images/Train_171.jpg')
img_171_label = train_data.iloc[171][:]

plt.imshow(cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB))
plt.show()
print(img_1_label)

plt.imshow(cv2.cvtColor(img_171, cv2.COLOR_BGR2RGB))
plt.show()
print(img_171_label)
# Out:
# image_id             Train_1
# healthy                    0
# multiple_diseases          1
# rust                       0
# scab                       0
# Name: 1, dtype: object
# image_id             Train_171
# healthy                      0
# multiple_diseases            0
# rust                         1
# scab                         0
# Name: 171, dtype: object

# %% [markdown]
# ### 내가 식물학자는 아니지만... 도대체 1번 사진의 multiple diseses와 171번 그림의 rust의 차이가 무엇인지?

# %% [markdown]
# ### 1등 한 사람이 사용했다는 knowledge distillation method 적용
#
# #### 1차 학습 결과를 0.3 가중치로 학습용 레이블로 적용 (원본 0.7 + 1차학습 0.3 = > 새로운 학습 레이블)
# #### 데이터 라벨링 실수를 중화하는 효과
