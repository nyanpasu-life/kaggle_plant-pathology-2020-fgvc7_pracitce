# %% [markdown]
# ### ImageDataGenerator 적용

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, LeakyReLU
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### 이미지 전처리

# %%
"./plant-pathology-2020-fgvc7/images/"

IMAGE_PATH = "./plant-pathology-2020-fgvc7/images/"
TEST_PATH = "./plant-pathology-2020-fgvc7/test.csv"
TRAIN_PATH = "./plant-pathology-2020-fgvc7/train.csv"
SUB_PATH = "./plant-pathology-2020-fgvc7/sample_submission.csv"

test_data = pd.read_csv(TEST_PATH)
train_data = pd.read_csv(TRAIN_PATH)

def load_image(image_id):
    file_path = image_id + ".jpg"
    image = cv2.imread(IMAGE_PATH + file_path)
    
    # 이미지 크기 확인
    height, width, _ = image.shape
    
    # 이미지 크기가 (2048, 1365)일 경우 회전하여 크기 변경
    if height == 2048 and width == 1365:
        image = np.rot90(image)

    # 이미지를 1/4 크기로 줄이기
    image = cv2.resize(image, (224, 224))

    return image

    #return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

train_images = train_data["image_id"][:].apply(load_image)

# %%
images = np.stack(train_images)
labels = train_data[["healthy", "multiple_diseases", "rust", "scab"]].values

# %%
from sklearn.model_selection import train_test_split
# 데이터를 균등하게 분할하여 검증 세트를 생성
train_images, val_images, train_labels, val_labels = train_test_split(images, labels, test_size=0.2, stratify=labels)

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   width_shift_range=0.1,
                                   height_shift_range=0.1,
                                   rotation_range=30,
                                   shear_range=0.7,
                                   zoom_range=[0.9, 2.2],
                                   fill_mode='nearest'
                                   )

val_datagen = ImageDataGenerator(rescale=1./255)

# %%
BATCH_SIZE = 5
train_generator = train_datagen.flow(x=train_images, y=train_labels, batch_size=BATCH_SIZE, shuffle=True)
val_generator = train_datagen.flow(x=val_images, y=val_labels, batch_size=BATCH_SIZE, shuffle=True)

# %%
model = Sequential()
model.add(Conv2D(16, kernel_size=(3,3), input_shape=(224,224,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(4,4)))
model.add(Conv2D(32, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(4,4)))
model.add(Conv2D(64, kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(4,4)))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(4, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 2s 0us/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4904\3626550436.py in <module>
#       8 model.add(MaxPooling2D(pool_size=(4,4)))
#       9 model.add(Flatten())
# ---> 10 model.add(Dense(32, activation='relu'))
#      11 model.add(Dense(16, activation='relu'))
#      12 model.add(Dense(4, activation='softmax'))
#
# c:\Users\USER\anaconda3\envs\tensorflowenv\lib\site-packages\tensorflow\python\trackable\base.py in _method_wrapper(self, *args, **kwargs)
#     203     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     204     try:
# --> 205       result = method(self, *args, **kwargs)
#     206     finally:
#     207       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# c:\Users\USER\anaconda3\envs\tensorflowenv\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# c:\Users\USER\anaconda3\envs\tensorflowenv\lib\site-packages\keras\layers\core\dense.py in build(self, input_shape)
#     147         if last_dim is None:
#     148             raise ValueError(
# --> 149                 "The last dimension of the inputs to a Dense layer "
#     150                 "should be defined. Found None. "
#     151                 f"Full input shape received: {input_shape}"
#
# ValueError: The last dimension of the inputs to a Dense layer should be defined. Found None. Full input shape received: (None, None)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 222, 222, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 55, 55, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 53, 53, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 11, 11, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 32)                8224
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 32,404
# Trainable params: 32,404
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 학습 및 검증
modelpath = './test.hdf5'
checkpointer = ModelCheckpoint(filepath=modelpath, monitor='val_loss', verbose=1, save_best_only=True)
early_stopping_callback = EarlyStopping(monitor='val_loss', patience=10)

history = model.fit(train_generator, epochs=70, verbose=1, callbacks=[early_stopping_callback, checkpointer], validation_data=val_generator)
# Out:
# Epoch 1/70
# 292/292 [==============================] - ETA: 0s - loss: 1.2625 - accuracy: 0.3372
# Epoch 1: val_loss improved from inf to 1.25045, saving model to .\test.hdf5
# 292/292 [==============================] - 18s 43ms/step - loss: 1.2625 - accuracy: 0.3372 - val_loss: 1.2505 - val_accuracy: 0.3781
# Epoch 2/70
# 292/292 [==============================] - ETA: 0s - loss: 1.2341 - accuracy: 0.3606
# Epoch 2: val_loss improved from 1.25045 to 1.20997, saving model to .\test.hdf5
# 292/292 [==============================] - 11s 38ms/step - loss: 1.2341 - accuracy: 0.3606 - val_loss: 1.2100 - val_accuracy: 0.4356
# Epoch 3/70
# 291/292 [============================>.] - ETA: 0s - loss: 1.0580 - accuracy: 0.5582
# Epoch 3: val_loss improved from 1.20997 to 0.81441, saving model to .\test.hdf5
# 292/292 [==============================] - 11s 38ms/step - loss: 1.0563 - accuracy: 0.5591 - val_loss: 0.8144 - val_accuracy: 0.6904
# Epoch 4/70
# 292/292 [==============================] - ETA: 0s - loss: 0.7855 - accuracy: 0.6793
# Epoch 4: val_loss improved from 0.81441 to 0.73124, saving model to .\test.hdf5
# 292/292 [==============================] - 11s 38ms/step - loss: 0.7855 - accuracy: 0.6793 - val_loss: 0.7312 - val_accuracy: 0.7014
# Epoch 5/70
# 292/292 [==============================] - ETA: 0s - loss: 0.6955 - accuracy: 0.7218
# Epoch 5: val_loss improved from 0.73124 to 0.62660, saving model to .\test.hdf5
# 292/292 [==============================] - 11s 38ms/step - loss: 0.6955 - accuracy: 0.7218 - val_loss: 0.6266 - val_accuracy: 0.7507
# Epoch 6/70
# 291/292 [============================>.] - ETA: 0s - loss: 0.6472 - accuracy: 0.7464
# Epoch 6: val_loss improved from 0.62660 to 0.60392, saving model to .\test.hdf5
# 292/292 [==============================] - 11s 38ms/step - loss: 0.6468 - accuracy: 0.7466 - val_loss: 0.6039 - val_accuracy: 0.7342
# Epoch 7/70
# 291/292 [============================>.] - ETA: 0s - loss: 0.6023 - accuracy: 0.7574
# Epoch 7: val_loss did not improve from 0.60392
# 292/292 [==============================] - 11s 38ms/step - loss: 0.6045 - accuracy: 0.7562 - val_loss: 0.6270 - val_accuracy: 0.7068
# Epoch 8/70
# 291/292 [============================>.] - ETA: 0s - loss: 0.6056 - accuracy: 0.7540
# Epoch 8: val_loss improved from 0.60392 to 0.56415, saving model to .\test.hdf5
# 292/292 [==============================] - 11s 38ms/step - loss: 0.6055 - accuracy: 0.7534 - val_loss: 0.5642 - val_accuracy: 0.7726
# Epoch 9/70
# 292/292 [==============================] - ETA: 0s - loss: 0.5649 - accuracy: 0.7850
# Epoch 9: val_loss improved from 0.56415 to 0.52327, saving model to .\test.hdf5
# 292/292 [==============================] - 11s 38ms/step - loss: 0.5649 - accuracy: 0.7850 - val_loss: 0.5233 - val_accuracy: 0.7726
# Epoch 10/70
# 291/292 [============================>.] - ETA: 0s - loss: 0.5376 - accuracy: 0.7981
# Epoch 10: val_loss did not improve from 0.52327
# 292/292 [==============================] - 11s 38ms/step - loss: 0.5373 - accuracy: 0.7981 - val_loss: 0.5753 - val_accuracy: 0.7863
# Epoch 11/70
# 292/292 [==============================] - ETA: 0s - loss: 0.5525 - accuracy: 0.7837
# Epoch 11: val_loss improved from 0.52327 to 0.51828, saving model to .\test.hdf5
# 292/292 [==============================] - 11s 39ms/step - loss: 0.5525 - accuracy: 0.7837 - val_loss: 0.5183 - val_accuracy: 0.7918
# Epoch 12/70
# 291/292 [============================>.] - ETA: 0s - loss: 0.5163 - accuracy: 0.7988
# Epoch 12: val_loss did not improve from 0.51828
# 292/292 [==============================] - 11s 38ms/step - loss: 0.5174 - accuracy: 0.7981 - val_loss: 0.5470 - val_accuracy: 0.7918
# Epoch 13/70
# 292/292 [==============================] - ETA: 0s - loss: 0.4853 - accuracy: 0.8077
# Epoch 13: val_loss improved from 0.51828 to 0.49330, saving model to .\test.hdf5
# 292/292 [==============================] - 11s 38ms/step - loss: 0.4853 - accuracy: 0.8077 - val_loss: 0.4933 - val_accuracy: 0.8027
# Epoch 14/70
# 292/292 [==============================] - ETA: 0s - loss: 0.5010 - accuracy: 0.8132
# Epoch 14: val_loss improved from 0.49330 to 0.45210, saving model to .\test.hdf5
# 292/292 [==============================] - 11s 38ms/step - loss: 0.5010 - accuracy: 0.8132 - val_loss: 0.4521 - val_accuracy: 0.8137
# Epoch 15/70
# 292/292 [==============================] - ETA: 0s - loss: 0.4890 - accuracy: 0.8359
# Epoch 15: val_loss improved from 0.45210 to 0.44812, saving model to .\test.hdf5
# 292/292 [==============================] - 11s 38ms/step - loss: 0.4890 - accuracy: 0.8359 - val_loss: 0.4481 - val_accuracy: 0.8247
# Epoch 16/70
# 291/292 [============================>.] - ETA: 0s - loss: 0.4524 - accuracy: 0.8415
# Epoch 16: val_loss did not improve from 0.44812
# 292/292 [==============================] - 11s 38ms/step - loss: 0.4512 - accuracy: 0.8420 - val_loss: 0.4953 - val_accuracy: 0.8055
# Epoch 17/70
# 291/292 [============================>.] - ETA: 0s - loss: 0.4273 - accuracy: 0.8429
# Epoch 17: val_loss improved from 0.44812 to 0.40641, saving model to .\test.hdf5
# 292/292 [==============================] - 11s 38ms/step - loss: 0.4262 - accuracy: 0.8434 - val_loss: 0.4064 - val_accuracy: 0.8329
# Epoch 18/70
# 292/292 [==============================] - ETA: 0s - loss: 0.4143 - accuracy: 0.8592
# Epoch 18: val_loss did not improve from 0.40641
# 292/292 [==============================] - 11s 39ms/step - loss: 0.4143 - accuracy: 0.8592 - val_loss: 0.4479 - val_accuracy: 0.8247
# Epoch 19/70
# 292/292 [==============================] - ETA: 0s - loss: 0.4076 - accuracy: 0.8558
# Epoch 19: val_loss did not improve from 0.40641
# 292/292 [==============================] - 11s 38ms/step - loss: 0.4076 - accuracy: 0.8558 - val_loss: 0.4467 - val_accuracy: 0.8438
# Epoch 20/70
# 292/292 [==============================] - ETA: 0s - loss: 0.4142 - accuracy: 0.8592
# Epoch 20: val_loss improved from 0.40641 to 0.33839, saving model to .\test.hdf5
# 292/292 [==============================] - 11s 38ms/step - loss: 0.4142 - accuracy: 0.8592 - val_loss: 0.3384 - val_accuracy: 0.8795
# Epoch 21/70
# 292/292 [==============================] - ETA: 0s - loss: 0.4039 - accuracy: 0.8695
# Epoch 21: val_loss did not improve from 0.33839
# 292/292 [==============================] - 11s 38ms/step - loss: 0.4039 - accuracy: 0.8695 - val_loss: 0.3855 - val_accuracy: 0.8575
# Epoch 22/70
# 291/292 [============================>.] - ETA: 0s - loss: 0.3946 - accuracy: 0.8677
# Epoch 22: val_loss did not improve from 0.33839
# 292/292 [==============================] - 11s 38ms/step - loss: 0.3937 - accuracy: 0.8681 - val_loss: 0.3958 - val_accuracy: 0.8575
# Epoch 23/70
# 291/292 [============================>.] - ETA: 0s - loss: 0.3728 - accuracy: 0.8642
# Epoch 23: val_loss did not improve from 0.33839
# 292/292 [==============================] - 11s 38ms/step - loss: 0.3717 - accuracy: 0.8647 - val_loss: 0.3773 - val_accuracy: 0.8740
# Epoch 24/70
# 292/292 [==============================] - ETA: 0s - loss: 0.3677 - accuracy: 0.8798
# Epoch 24: val_loss did not improve from 0.33839
# 292/292 [==============================] - 11s 38ms/step - loss: 0.3677 - accuracy: 0.8798 - val_loss: 0.4260 - val_accuracy: 0.8329
# Epoch 25/70
# 291/292 [============================>.] - ETA: 0s - loss: 0.3753 - accuracy: 0.8746
# Epoch 25: val_loss improved from 0.33839 to 0.33626, saving model to .\test.hdf5
# 292/292 [==============================] - 11s 38ms/step - loss: 0.3750 - accuracy: 0.8743 - val_loss: 0.3363 - val_accuracy: 0.8849
# Epoch 26/70
# 292/292 [==============================] - ETA: 0s - loss: 0.3662 - accuracy: 0.8702
# Epoch 26: val_loss did not improve from 0.33626
# 292/292 [==============================] - 11s 38ms/step - loss: 0.3662 - accuracy: 0.8702 - val_loss: 0.4332 - val_accuracy: 0.8712
# Epoch 27/70
# 292/292 [==============================] - ETA: 0s - loss: 0.3430 - accuracy: 0.8839
# Epoch 27: val_loss did not improve from 0.33626
# 292/292 [==============================] - 11s 38ms/step - loss: 0.3430 - accuracy: 0.8839 - val_loss: 0.3658 - val_accuracy: 0.8575
# Epoch 28/70
# 292/292 [==============================] - ETA: 0s - loss: 0.3584 - accuracy: 0.8805
# Epoch 28: val_loss did not improve from 0.33626
# 292/292 [==============================] - 11s 38ms/step - loss: 0.3584 - accuracy: 0.8805 - val_loss: 0.3517 - val_accuracy: 0.8877
# Epoch 29/70
# 292/292 [==============================] - ETA: 0s - loss: 0.3525 - accuracy: 0.8867
# Epoch 29: val_loss did not improve from 0.33626
# 292/292 [==============================] - 11s 39ms/step - loss: 0.3525 - accuracy: 0.8867 - val_loss: 0.3971 - val_accuracy: 0.8795
# Epoch 30/70
# 291/292 [============================>.] - ETA: 0s - loss: 0.3584 - accuracy: 0.8780
# Epoch 30: val_loss did not improve from 0.33626
# 292/292 [==============================] - 11s 38ms/step - loss: 0.3608 - accuracy: 0.8777 - val_loss: 0.3674 - val_accuracy: 0.8740
# Epoch 31/70
# 292/292 [==============================] - ETA: 0s - loss: 0.3266 - accuracy: 0.8880
# Epoch 31: val_loss did not improve from 0.33626
# 292/292 [==============================] - 11s 38ms/step - loss: 0.3266 - accuracy: 0.8880 - val_loss: 0.3693 - val_accuracy: 0.8767
# Epoch 32/70
# 292/292 [==============================] - ETA: 0s - loss: 0.3525 - accuracy: 0.8846
# Epoch 32: val_loss did not improve from 0.33626
# 292/292 [==============================] - 11s 39ms/step - loss: 0.3525 - accuracy: 0.8846 - val_loss: 0.3545 - val_accuracy: 0.8740
# Epoch 33/70
# 292/292 [==============================] - ETA: 0s - loss: 0.3262 - accuracy: 0.8887
# Epoch 33: val_loss did not improve from 0.33626
# 292/292 [==============================] - 11s 39ms/step - loss: 0.3262 - accuracy: 0.8887 - val_loss: 0.3431 - val_accuracy: 0.8740
# Epoch 34/70
# 292/292 [==============================] - ETA: 0s - loss: 0.3281 - accuracy: 0.8846
# Epoch 34: val_loss did not improve from 0.33626
# 292/292 [==============================] - 11s 38ms/step - loss: 0.3281 - accuracy: 0.8846 - val_loss: 0.3877 - val_accuracy: 0.8658
# Epoch 35/70
# 292/292 [==============================] - ETA: 0s - loss: 0.3229 - accuracy: 0.8915
# Epoch 35: val_loss did not improve from 0.33626
# 292/292 [==============================] - 11s 38ms/step - loss: 0.3229 - accuracy: 0.8915 - val_loss: 0.3679 - val_accuracy: 0.8822

# %%
# 6 훈련 과정 시각화 (정확도)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# 7 훈련 과정 시각화 (손실)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
